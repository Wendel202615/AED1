# %%
print('meu nome é wendel')
# Out:
# meu nome é wendel

# %%
print('meu RA é 3011542623038')
# Out:
# meu RA é 3011542623038

# %%
print('Escolhi este curso porque quero trabalhar com dados')
# Out:
# Escolhi este curso porque quero trabalhar com dados

# %%
print('Meu nome é Wendel. Estou começando a trabalhar com programação. Quero aprender a transformar problemas em instruções para computador')
# Out:
# Meu nome é Wendel. Estou começando a trabalhar com programação. Quero aprender a transformar problemas em instruções para computador

# %%
print('Esta é a minha primeira mensagem executada em python')
# Out:
# Esta é a minha primeira mensagem executada em python

# %%
print('meu nome é Wendel')
print('Curso: Ciência de Dados para Negocios')
print('Disciplina:Algoritmos e programação com IA')
print('Meta:Aprender a resolver problemas com programação')
# Out:
# meu nome é Wendel
# Curso: Ciência de Dados para Negocios
# Disciplina:Algoritmos e programação com IA
# Meta:Aprender a resolver problemas com programação

# %%
print('Sistemas de vendas CDN')
print('Bem vindo ao painel inicial')
print('Os dados de vendas ainda serão carregados')
print('Aguarde a proxima etapa para iniciar a analise')
# Out:
# Sistemas de vendas CDN
# Bem vindo ao painel inicial
# Os dados de vendas ainda serão carregados
# Aguarde a proxima etapa para iniciar a analise

# %%
print('Notbook de estudos - Algoritmos e programação com IA')
print('Semana I,Introdução ao ambiente de programação')
# Out:
# Notbook de estudos - Algoritmos e programação com IA
# Semana I,Introdução ao ambiente de programação
