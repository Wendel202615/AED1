# %%
print('Cap02, Por dentro da máquina')
# Out:
# Cap02, Por dentro da máquina

# %%
print('2**8')
print(ord('A'))
print(chr(65))
# Out:
# 2**8
# 65
# A

# %%
for char in 'a,d,z,p,s'.replace(' ', '').split(','):
    print(f"ord('{char}'): {ord(char)}")

for num_str in '65,68,80,90,53'.split(','):
    num = int(num_str)
    print(f"chr({num}): {chr(num)}")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_1408/919953737.py in <cell line: 0>()
# ----> 1 print(ord ('a, d, z ,p, s'))
#       2 print(chr ('65,68,80,90,53'))
#
# TypeError: ord() expected a character, but string of length 13 found

# %%
print(f'ord(a,d,z,p,s)'): ord('65,68,80,90,53')
# Out:
#   File "/tmp/ipykernel_2532/1552834513.py", line 1
#     print(f'ord(a,d,z,p,s)'): ord('65,68,80,90,53')
#     ^
# SyntaxError: illegal target for annotation

# %%
for char in 'a,d,z,p,s'.split(','):
    print(f"ord('{char}'): {ord(char)}")

for num_str in '65,68,80,90,53'.split(','):
    num = int(num_str)
    print(f"chr({num}): {chr(num)}")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_2532/4248626227.py in <cell line: 0>()
# ----> 1 print(ord ('a,d,z,p,s'))
#       2 print(chr ('65,68,80,90,53'))
#
# TypeError: ord() expected a character, but string of length 9 found

# %%
print(ord('a'))(ord('d'))(ord('z'))(ord('p'))(ord('s'))
print(chr(65))(chr(68))(chr(80))(chr(90))(chr(53))
# Out:
# 97
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_2532/396977995.py in <cell line: 0>()
# ----> 1 print(ord('a'))(ord('d'))(ord('z'))(ord('p'))(ord('s'))
#       2 print(chr(65))(chr(68))(chr(80))(chr(90))(chr(53))
#
# TypeError: 'NoneType' object is not callable

# %%
print(ord('a'))
print(ord('d'))
print(ord('z'))
print(ord('p'))
print(ord('s'))
# Out:
# 97
# 100
# 122
# 112
# 115

# %%
print(chr(65))
print(chr(68))
print(chr(80))
print(chr(90))
print(chr(53))
# Out:
# A
# D
# P
# Z
# 5

# %%
print(ord('w'))
print(ord('e'))
print(ord('n'))
print(ord('d'))
print(ord('e'))
print(ord('l'))
# Out:
# 119
# 101
# 110
# 100
# 101
# 108

# %%
print(chr(119))
print(chr(101))
print(chr(110))
print(chr(100))
print(chr(101))
print(chr(108))
# Out:
# w
# e
# n
# d
# e
# l

# %%
print(119-65)
# Out:
# 54

# %%
print(ord('i'))
print(ord('s'))
print(ord('a'))
print(ord('b'))
print(ord('e'))
print(ord('l'))
print(ord('a'))
# Out:
# 105
# 115
# 97
# 98
# 101
# 108
# 97

# %%
print(105-65)
# Out:
# 40

# %%
print(ord('w'), ord('e'), ord('n'), ord('d'), ord('e'), ord('l'))
# Out:
# 119 101 110 100 101 108

# %%
print(chr(119))
# Out:
# w

# %%
print(chr(101), chr(110), chr(100), chr(101), chr(108))
# Out:
# e n d e l

# %%
nome = input('Qual seu nome?')
# Out:
# Qual seu nome?wendel

# %%
print('Olá seja bem vindo', nome)
# Out:
# Olá seja bem vindo wendel

# %%
print('letra,''w', ord('w'))
print('letra,''e', ord('e'))
print('letra,''n', ord('n'))
print('letra,''d', ord('d'))
print('letra,''e', ord('e'))
print('letra,''l', ord('l'))
# Out:
# letra,w 119
# letra,e 101
# letra,n 110
# letra,d 100
# letra,e 101
# letra,l 108

# %%
print('Exercício 5')
# Out:
# Exercício 5

# %%
print(chr(67))
print(chr(68))
print(chr(78))
# Out:
# C
# D
# N

# %%
codigo = ord('w',) + ord('e') + ord('n')
+ ord('d') + ord('e') + ord('l')
# Out:
# 309

# %%
binario = format(codigo, '08b') + format(codigo, '08b') + format(codigo, '08b')+ format(codigo, '08b') + format(codigo, ' 08b') + format(codigo, '08b')

# %%
print('w', codigo, binario)
# Out:
# w 119 01110111

# %%
codido = ord('e')
codigo = ord('n')
codigo = ord('d')
codigo = ord('e')
codigo = ord('l')

# %%
print(('e'), codigo, binario)
# Out:
# e 108 01101100

# %%
print(('n'), codigo, binario)
print(('d'), codigo, binario)
print(('e'), codigo, binario)
print(('l'), codido, binario)
# Out:
# n 108 01101100
# d 108 01101100
# e 108 01101100
# l 101 01101100

# %%
print('Exercício 7, tamanho do aquivo')
# Out:
# Exercício 7, tamanho do aquivo

# %%
taxa_kbps = 128
tempo_min = 3

# %%
taxa_bps = 128 * 1000
tempo_seg = 3 * 60

# %%
total_bits = 128 * 1000 * 3 * 60
total_bytes =total_bits / 8
total_mb = total_bytes / 1_000_000

# %%
print(f'Total de bits: {total_bits}')
print(f'total de bytes: {total_bytes}')
print(f'Tamanho aproximado: {total_mb}')
# Out:
# Total de bits: 23040000
# total de bytes: 2880000.0
# Tamanho aproximado: 2.88

# %%
print("Exercicio 8")
# Out:
# Exercicio 8

# %%
print(ord('A'))
print(ord('B'))
# Out:
# 65
# 66

# %%
print(ord('A'))
print(ord('a'))
print(ord('Z'))
print(ord('z'))
# Out:
# 65
# 97
# 90
# 122

# %%
print("SOROCABA" == ("sorocaba"))
# Out:
# False

# %%
print('exercicio 10')
# Out:
# exercicio 10

# %%
print(ord(' '))
# Out:
# 32

# %%
print(chr(67))
print(chr(84))
print(chr(78))
# Out:
# C
# T
# N

# %%
print(codigo, '65, 91', [chr(num) for num in codigo])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_10923/3428795874.py in <cell line: 0>()
# ----> 1 print(codigo, '65, 91', chr(codigo))
#
# TypeError: 'tuple' object cannot be interpreted as an integer

# %%
codigo = 65
print(codigo, '65, 91', chr(codigo))
# Out:
# 65 65, 91 A

# %%
inicio = 65
fim = 90

# %%
print(codigo, '65, 90', chr(codigo))
# Out:
# 65 65, 90 A

# %%
palavra = 'FATEC'

# %%
print('letra | decimal | binario')
# Out:
# letra | decimal | binario

# %%
print('FATEC' * 30)
# Out:
# FATECFATECFATECFATECFATECFATECFATECFATECFATECFATECFATECFATECFATECFATECFATECFATECFATECFATECFATECFATECFATECFATECFATECFATECFATECFATECFATECFATECFATECFATEC

# %%
print(codigo), ord('F')
# Out:
# 65
# (None, 70)

# %%
binario = format(70, '08b')

# %%
print('Professor, não entendi muito bem esse final')
# Out:
# Professor, não entendi muito bem esse final
