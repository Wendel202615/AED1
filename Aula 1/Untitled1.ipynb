# %%
print('Sistemas de vendas CDN')
print('Bem vindo ao paniel inicial')
print('Os dados de vendas ainda serão carregados')
print('Aguarde a proxima etapa para iniciar a ánalise')
# Out:
# Sistemas de vendas CDN
# Bem vindo ao paniel inicial
# Os dados de vendas ainda serão carregados
# Aguarde a proxima etapa para iniciar a ánalise

# %%
print('notbook de estudos - algoritmos e programação com IA')
print('Semana 1 - Introdução ao ambiente de programação')
# Out:
# notbook de estudos - algoritmos e programação com IA
# Semana 1 - Introdução ao ambiente de programação

# %%
print('Oi! este é o meu primeiro notbook de python')
print('Ainda estou aprendendo, mas ja estou conseguindo executar codigo')
# Out:
# Oi! este é o meu primeiro notbook de python
# Ainda estou aprendendo, mas ja estou conseguindo executar codigo

# %%
print('Notbook: cap01_Wendelvieira.ipynb')
print('Ambiente: Google colab | Lianguagem Python')
# Out:
# Notbook: cap01_Wendelvieira.ipynb
# Ambiente: Google colab | Lianguagem Python

# %%
print('Ola mundo, o erro acontece poque a frase não estre entre os parenteses')
# Out:
# Ola mundo, o erro acontece poque a frase não estre entre os parenteses

# %%
print('Bem vindo ao curso')
# Out:
# Bem vindo ao curso

# %%
print('Nome: Wendel Vieira')
print('Curso: Ciência de dados para negocios')
print('Disciplina: Algoritmos e Programação com IA')
print('Habilidade que quero desenvolver: Resolver problemas com codigos')
print('Dificuldade que imagino: Entender as mensagem de erro de Python')
print('Sobre IA: vou usar para estudar, mas sempre vou testar e explicar o codigo')
# Out:
# Nome: Wendel Vieira
# Curso: Ciência de dados para negocios
# Disciplina: Algoritmos e Programação com IA
# Habilidade que quero desenvolver: Resolver problemas com codigos
# Dificuldade que imagino: Entender as mensagem de erro de Python
# Sobre IA: vou usar para estudar, mas sempre vou testar e explicar o codigo

# %%
print('Ir ao banco')
print('Usar o caixa eletronico')
print('Pegar o dinheiro')
# Out:
# Ir ao banco
# Usar o caixa eletronico
# Pegar o dinheiro

# %%
print('Inserir o cartão no caixa eletronico')
print('Digitar a senha de quatro digitos')
print('Selecionar a opção saque')
print('Escolher a conta de origem, (poupança ou corrente )')
print('Digitar o valor desejado')
print('Confirmar a operação')
print('Retirar o dinheiro da gaveta')
print('Retirar o cartão')
# Out:
# Inserir o cartão no caixa eletronico
# Digitar a senha de quatro digitos
# Selecionar a opção saque
# Escolher a conta de origem, (poupança ou corrente )
# Digitar o valor desejado
# Confirmar a operação
# Retirar o dinheiro da gaveta
# Retirar o cartão

# %%
print('Nome cliente: Wendel Vieira')
print('Cpf: 45882617898')
print('Contato: 15997670752')
print('Email: wendelvieira976@gmail.com')
print('Todos os campos fora preenchidos')
print('Cpf cadastrado, ja consta no sistema')
print('Cadastro concluido')
# Out:
# Nome cliente: Wendel Vieira
# Cpf: 45882617898
# Contato: 15997670752
# Email: wendelvieira976@gmail.com
# Todos os campos fora preenchidos
# Cpf cadastrado, ja consta no sistema
# Cadastro concluido

# %%
print('Chatgpt me passou a forma de usar f-string')
# Out:
# Chatgpt me passou a forma de usar f-string

# %%
print(f'meu nome é wendel e tenho 24 anos')
# Out:
# meu nome é wendel e tenho 24 anos

# %%
print(f'O produto é tapete e custa R$50')
# Out:
# O produto é tapete e custa R$50

# %%
print(f'Olá wendel')
# Out:
# Olá wendel

# %%
print(f'Tapetes, custa R$50, 2 unidades')
# Out:
# Tapetes, custa R$50, 2 unidades

# %%
print(f'Tapetes Personalizados')
print(f'Custa R$100')
print(f'2Unidades')
# Out:
# Tapetes Personalizados
# Custa R$100
# 2Unidades

# %%
print(f"Modelo que a IA me passou, funciounou ")
# Out:
# Modelo que a IA me passou, funciounou

# %%
print('Exercício 15')
# Out:
# Exercício 15
