# %%
Titulo = ('Capitulo03')

# %%
print('Capitulo03, Wendel')
# Out:
# Capitulo03, Wendel

# %%
5 * 8
# Out:
# 40

# %%
print(2 * 2 * 2 * 2 * 2 * 2 * 2)
# Out:
# 128

# %%
print(2 ** 0)
# Out:
# 1

# %%
int('00001010', 2)
# Out:
# 10

# %%
int('11111111', 2)
# Out:
# 255

# %%
bin(13)
# Out:
# '0b1101'

# %%
bin(42)
# Out:
# '0b101010'

# %%
bin(7)
# Out:
# '0b111'

# %%
int('1101', 2)
# Out:
# 13

# %%
numeros = [13, 42, 7, 100, 255]
for n in numeros:
  print(f'{n:3d} -> {bin(n)} -> {n:08b}')
# Out:
#  13 -> 0b1101 -> 00001101
#  42 -> 0b101010 -> 00101010
#   7 -> 0b111 -> 00000111
# 100 -> 0b1100100 -> 01100100
# 255 -> 0b11111111 -> 11111111

# %%
0b1100100
# Out:
# 100

# %%
largura = 1920
altura = 1080
bytes_por_pixel = 3
tamanho_bytes = 1920 * 1080 * 3
tamanho_kb = tamanho_bytes / 1024
tamanho_mb = tamanho_kb / 1024
print(f'pixels total: {largura * altura}')
print(f'tamanho: {tamanho_bytes:,} bytes')
print(f'tamanho: {tamanho_kb:,.0f} kb')
print(f'tamanho: {tamanho_mb:,.2f} mb')
# Out:
# pixels total: 2073600
# tamanho: 6,220,800 bytes
# tamanho: 6,075 kb
# tamanho: 5.93 mb

# %%
hd = 1280 * 720 * 3
print(f'HD 1280*720: {hd:,} bytes ({hd/1024/1024:.2f} mb)')
# Out:
# HD 1280*720: 2,764,800 bytes (2.64 mb)

# %%
k4 = 3840 * 2160 * 3
print(f'4k 3840*2160: {k4:,} bytes ({k4/1024/1024:.2f} mb)')
# Out:
# 4k 3840*2160: 24,883,200 bytes (23.73 mb)

# %%
proporcao = k4 / hd
print(f' A imagem 4k é {proporcao:.0f}x maior que a 1280*720')
# Out:
#  A imagem 4k é 9x maior que a 1280*720

# %%
freq_amostragem = 44100
bites_por_amostra = 16
canais = 2
duracao_min = 10
duracao_seg = 10 * 60
bytes_amostra = 16 // 8
tamanho_bytes = freq_amostragem * bytes_amostra * canais * duracao_seg
tamanho_mb = tamanho_bytes / 100480576
print(f'duraçao: {duracao_seg} segundos')
print(f'tamanho: {tamanho_bytes:,} bytes')
print(f'tamanho_mb: {tamanho_mb:.2f} MB')
# Out:
# duraçao: 600 segundos
# tamanho: 105,840,000 bytes
# tamanho_mb: 1.05 MB

# %%
largura = 1920
altura = 1080
tamanho = 1920 * 1080
print(tamanho)
# Out:
# 2073600

# %%
largura = 1920
altura = 1080
bytes_por_pixel = 3
tamanho = 1920 * 1080 * 3
print(f'{tamanho:,} bytes')
# Out:
# 6,220,800 bytes

# %%
largura = 2500
altura = 1500
tamanho = 2500 * 1500 * 3
print(f'{tamanho:,} bytes')
# Out:
# 11,250,000 bytes

# %%
largura = 1920
altura = 1080
bytes_por_pixel = 3
tamanho_bytes = 1920 * 1080 * 3
tamanho_kb = tamanho_bytes / 1024
tamanho_mb = tamanho_kb / 1024
print(f'imagem: {largura} * {altura} pixel')
print(f'tamanho: {tamanho_bytes:,} bytes')
print(f'tamanho: {tamanho_kb:.2f} kb')
print(f'tamanho: {tamanho_mb:.2f} mb')
# Out:
# imagem: 1920 * 1080 pixel
# tamanho: 6,220,800 bytes
# tamanho: 6075.00 kb
# tamanho: 5.93 mb

# %%
largura = 8000
altura = 9000
bytes_por_pixel = 3
tamanho_bytes = 8000 * 9000 * 3
tamanho_kb = tamanho_bytes / 1024
tamanho_mb = tamanho_kb / 1024
print(f'imagem: {largura} x {altura} pixel')
print(f'tamanho: {tamanho_bytes:,} bytes')
print(f'tamanho: {tamanho_kb:.2f} kb')
print(f'tamanho: {tamanho_mb:.2f} mb')
# Out:
# imagem: 8000 x 9000 pixel
# tamanho: 216,000,000 bytes
# tamanho: 210937.50 kb
# tamanho: 205.99 mb

# %%
largura = 1
altura = 1
bytes_por_pixel = 3
tamanho_bytes = 1 * 1 * 3
tamanho_k = tamanho_bytes / 1024
tamanho_mb = tamanho_kb / 1024
print(f'imagem: {largura} x {altura} pixel')
print(f'tamanho: {tamanho_bytes:,} bytes')
print(f'tamanho: {tamanho_kb:.2f} kb')
print(f'tamanho: {tamanho_mb:.2f}')
# Out:
# imagem: 1 x 1 pixel
# tamanho: 3 bytes
# tamanho: 210937.50 kb
# tamanho: 205.99

# %%
# Wendel Maximo Vieira
# RA: 3011542623038
# Curso: Ciência de Dados
# Data: 21/9/2026
# Sobre mim
print('tenho interesse em aprender Ciência de dados e Inteligencia Artificial')
# Oque aprendi sobre bytes
print('aprendi que o computador guarda tudo em 0 e 1')
print('um bit valo 0 ou 1, byte vale 8 bits')
print('uma grade colorida é uma grade de pixels RGB')
# Out:
# tenho interesse em aprender Ciência de dados e Inteligencia Artificial
# aprendi que o computador guarda tudo em 0 e 1
# um bit valo 0 ou 1, byte vale 8 bits
# uma grade colorida é uma grade de pixels RGB

# %%
resolucoes = [(640 , 480, 'VGA'), (1920, 1080, 'Full HD'), (3840, 2160, '4k')]
for larg, alt, nome in resolucoes:
  tam = larg * alt * 3
  mb = tam / 1024 / 1024
  print(f'{nome:.8s} {larg} * {alt:4d} -> {tam:,} bytes (mb:.1f) MB)')
# Out:
# VGA 640 *  480 -> 921,600 bytes (mb:.1f) MB)
# Full HD 1920 * 1080 -> 6,220,800 bytes (mb:.1f) MB)
# 4k 3840 * 2160 -> 24,883,200 bytes (mb:.1f) MB)

# %%
qtde_imagens = 50_000
largura = 1920
altura = 1080
bytes_por_pixel = 3
bytes_por_imagem = 1920 * 1080 * 3
total_bytes = bytes_por_imagem * 50_000
total_gb = total_bytes / 1024**3
mb_unit = bytes_por_imagem / 1024 / 1024
print(f'por imagem: {bytes_por_imagem:,} bytes ({mb_unit:.1f}) mb')
print(f'total bruto: {total_bytes:,} bytes')
print(f'total bruto: {total_gb:.2f} gb')
# Out:
# por imagem: 6,220,800 bytes (5.9) mb
# total bruto: 311,040,000,000 bytes
# total bruto: 289.68 gb

# %%
kb_por_imagem_jpeg = 500
total_kb_jpeg = 500 * 50_000
total_gb_jpeg = total_kb_jpeg / 1024
print(f'toal jpeg: {total_kb_jpeg:,} kb')
print(f'toal jpeg: {total_gb_jpeg:.2f} gb')
reducao = total_bytes / (total_kb_jpeg * 1024)
print(f'reducao: {reducao:.1f} x menor espaco de jpeg')
# Out:
# toal jpeg: 25,000,000 kb
# toal jpeg: 24414.06 gb
# reducao: 12.2 x menor espaco de jpeg

# %%
gb = 1024
mb = 1024 * 1024
kb = 1024 * 1024 * 1024

# %%
bin (42)
# Out:
# '0b101010'

# %%
largura = 1920
altura = 1080
bits_por_canal = 8
canais = 3
bits = 1920 * 1080 * 3 * 8
bytes = bits / 8
megabytes = bytes / (1024**2)
print('tamanho de imagem:')
print(f'{megabytes:.2f} mb')
# Out:
# tamanho de imagem:
# 5.93 mb

# %%
largura = 1920
altura = 1080
bytes_por_pixel = 3
tamanho_bytes = 1920 * 1080 * 3
tamanho_kb = tamanho_bytes / 1024
tamanho_mb = tamanho_kb / 1024
print(f'tamanho em bytes: {tamanho_bytes:,}')
print(f'tamanho em kb: {tamanho_kb:.2f}kb')
print(f'tamnho em mb: {tamanho_mb:.2f} mb')
# Out:
# tamanho em bytes: 6,220,800
# tamanho em kb: 6075.00kb
# tamnho em mb: 5.93 mb
